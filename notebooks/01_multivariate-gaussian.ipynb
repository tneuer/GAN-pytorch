# %% [markdown]
# # Sampling from a multivariate Gaussian using a GAN
# In this example we'll try to learn a generator sampling from a simple $N$-dimensional multivariate Gaussian.

# %%
import os
import torch

import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt

os.chdir("/home/thomas/Backup/Algorithmen/GAN-pytorch")
from vegans.GAN import WassersteinGAN
from vegans.utils.utils import plot_losses

# %%
z_dim = 32  # noise vector size
N = 20  # size of sampled vectors

# %% [markdown]
# ## Prepare the "training" dataset
# First, we define a $NxN$ covariance matrix, and plot it:

# %%
cov_mat = np.zeros(shape=(N, N))
cov_mat[0:10, 0:10] = 0.8
np.fill_diagonal(cov_mat, 1.)

plt.imshow(cov_mat)
plt.title('Data generating process covariance matrix')
plt.colorbar();

# %% [markdown]
# Our goal will be to train a generator network in a GAN setting, which can sample from a distribution with a similar covariance matrix.
#
# For reference, here's the sample covariance matrix, obtained when sampling from this distribution:

# %%
X_train = np.random.multivariate_normal(mean=np.array([0. for _ in range(N)]), cov=cov_mat, size=10000)

# re-cover matrix
cov_mat_recovered = np.cov(X_train.T)

plt.imshow(cov_mat_recovered)
plt.title('Sample cov matrix from multivariate Gaussian');
plt.colorbar();

# %% [markdown]
# Let's now have a look at the distribution of our (flattened) training set:

# %%
plt.hist(X_train.flatten(), bins=50)
plt.title('Histogram of (flattened) training set samples');

# %% [markdown]
# ## Define our Generator and Critic Networks
# Here we'll define some very simple nets.

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.hidden_part = nn.Sequential(
            nn.Linear(z_dim, 32),
            nn.LeakyReLU(0.1),
        )
        self.output = nn.Linear(32, 20)

    def forward(self, x):
        x = self.hidden_part(x)
        x = self.output(x)
        return x

class Critic(nn.Module):
    def __init__(self):
        super(Critic, self).__init__()
        self.hidden_part = nn.Sequential(
            nn.Linear(N, 10),
            nn.LeakyReLU(0.1),
            nn.Linear(10, 1)
        )
        self.output = nn.Identity()

    def forward(self, x):
        x = self.hidden_part(x)
        x = self.output(x)
        return x
    
critic = Critic()
generator = Generator()

# %% [markdown]
# We didn't train our generator yet, so it's just generating noise. What does the sample covariance matrix look like?

# %%
def plot_generator_cov(generator, n=10000):
    """ Try the generator on a noise mini-batch and compute sample covariance matrix
    """
    z = torch.from_numpy(np.random.randn(n, z_dim)).float()
    samples = generator(z)
    cov_mat_est = np.cov(samples.detach().numpy().T)
    plt.imshow(cov_mat_est)
    plt.title('sample covariance matrix from generator network');
    plt.colorbar();
    
plot_generator_cov(generator)

# %% [markdown]
# ## Time for training!
# We'll use [WGAN-GP](https://arxiv.org/abs/1704.00028). Here we'll define our own optimizers for the generator and the critic, in order to use a slightly lower learning rate than the default one.
#
# We'll train for 50 epochs.
#
# We set `folder=None` so that no folder is created where all results would be stored. Otherwise we could give a path like `folder="TrainedModels/GAN"`. All results (summary, images, loss functions, tensorboard information, models) would be saved in that folder. You can control what should be saved in the `fit` method. This folder will never overwrite an existing folder. If the path already exists a new path of the form `folder=path_{TimeStamp}` is created.

# %%
optimizer = {
    "Generator": torch.optim.Adam,
    "Adversariat": torch.optim.Adam
}
optimizer_kwargs = {
    "Generator": {"lr": 0.0001, "betas": (0.5, 0.999)},
    "Adversariat": {"lr": 0.0001, "betas": (0.5, 0.999)},
}

gan = WassersteinGAN(
    generator, critic, z_dim=z_dim, x_dim=N, ngpu=ngpu, 
    optim=optimizer, optim_kwargs=optimizer_kwargs, device="cpu", folder=None
)

# %% [markdown]
# The training happens in the next cell. You can interrupt it at any time without loosing the results.

# %%
gan.fit(X_train, epochs=25, print_every="1e", enable_tensorboard=False)
# Out:
# ------------------------------------------------------------
# EPOCH: 1
# ------------------------------------------------------------
# Step: 313 / 6260 (Epoch: 1 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.009285424835979939
# Adversariat: -0.0007203631103038788
# Adversariat_fake: 0.009285424835979939
# Adversariat_real: -0.010726151056587696
#
#
# Time left: ~0.194 minutes (Batches remaining: 5947).
#
#
# ------------------------------------------------------------
# EPOCH: 2
# ------------------------------------------------------------
# Step: 626 / 6260 (Epoch: 2 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.009559359401464462
# Adversariat: -0.00088504608720541
# Adversariat_fake: 0.009559359401464462
# Adversariat_real: -0.011329451575875282
#
#
# Time left: ~0.173 minutes (Batches remaining: 5634).
#
#
# ------------------------------------------------------------
# EPOCH: 3
# ------------------------------------------------------------
# Step: 939 / 6260 (Epoch: 3 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.00988022331148386
# Adversariat: -0.0008803410455584526
# Adversariat_fake: 0.00988022331148386
# Adversariat_real: -0.011640905402600765
#
#
# Time left: ~0.162 minutes (Batches remaining: 5321).
#
#
# ------------------------------------------------------------
# EPOCH: 4
# ------------------------------------------------------------
# Step: 1252 / 6260 (Epoch: 4 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.009885681793093681
# Adversariat: -0.0008207368664443493
# Adversariat_fake: 0.009885681793093681
# Adversariat_real: -0.01152715552598238
#
#
# Time left: ~0.154 minutes (Batches remaining: 5008).
#
#
# ------------------------------------------------------------
# EPOCH: 5
# ------------------------------------------------------------
# Step: 1565 / 6260 (Epoch: 5 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.009458629414439201
# Adversariat: -0.0007763099856674671
# Adversariat_fake: 0.009458629414439201
# Adversariat_real: -0.011011249385774136
#
#
# Time left: ~0.142 minutes (Batches remaining: 4695).
#
#
# ------------------------------------------------------------
# EPOCH: 6
# ------------------------------------------------------------
# Step: 1878 / 6260 (Epoch: 6 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.00921054556965828
# Adversariat: -0.0007389131933450699
# Adversariat_fake: 0.00921054556965828
# Adversariat_real: -0.01068837195634842
#
#
# Time left: ~0.132 minutes (Batches remaining: 4382).
#
#
# ------------------------------------------------------------
# EPOCH: 7
# ------------------------------------------------------------
# Step: 2191 / 6260 (Epoch: 7 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.009348003193736076
# Adversariat: -0.0007671299390494823
# Adversariat_fake: 0.009348003193736076
# Adversariat_real: -0.010882263071835041
#
#
# Time left: ~0.123 minutes (Batches remaining: 4069).
#
#
# ------------------------------------------------------------
# EPOCH: 8
# ------------------------------------------------------------
# Step: 2504 / 6260 (Epoch: 8 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.009372164495289326
# Adversariat: -0.0008110757917165756
# Adversariat_fake: 0.009372164495289326
# Adversariat_real: -0.010994316078722477
#
#
# Time left: ~0.113 minutes (Batches remaining: 3756).
#
#
# ------------------------------------------------------------
# EPOCH: 9
# ------------------------------------------------------------
# Step: 2817 / 6260 (Epoch: 9 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.009835283271968365
# Adversariat: -0.000800140667706728
# Adversariat_fake: 0.009835283271968365
# Adversariat_real: -0.01143556460738182
#
#
# Time left: ~0.104 minutes (Batches remaining: 3443).
#
#
# ------------------------------------------------------------
# EPOCH: 10
# ------------------------------------------------------------
# Step: 3130 / 6260 (Epoch: 10 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.01008626539260149
# Adversariat: -0.000655855517834425
# Adversariat_fake: 0.01008626539260149
# Adversariat_real: -0.01139797642827034
#
#
# Time left: ~0.094 minutes (Batches remaining: 3130).
#
#
# ------------------------------------------------------------
# EPOCH: 11
# ------------------------------------------------------------
# Step: 3443 / 6260 (Epoch: 11 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.01045537181198597
# Adversariat: -0.0005336259491741657
# Adversariat_fake: 0.01045537181198597
# Adversariat_real: -0.011522623710334301
#
#
# Time left: ~0.084 minutes (Batches remaining: 2817).
#
#
# ------------------------------------------------------------
# EPOCH: 12
# ------------------------------------------------------------
# Step: 3756 / 6260 (Epoch: 12 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010900112800300121
# Adversariat: -0.00013742083683609962
# Adversariat_fake: 0.010900112800300121
# Adversariat_real: -0.01117495447397232
#
#
# Time left: ~0.075 minutes (Batches remaining: 2504).
#
#
# ------------------------------------------------------------
# EPOCH: 13
# ------------------------------------------------------------
# Step: 4069 / 6260 (Epoch: 13 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010036670602858067
# Adversariat: -0.0001737014390528202
# Adversariat_fake: 0.010036670602858067
# Adversariat_real: -0.010384073480963707
#
#
# Time left: ~0.066 minutes (Batches remaining: 2191).
#
#
# ------------------------------------------------------------
# EPOCH: 14
# ------------------------------------------------------------
# Step: 4382 / 6260 (Epoch: 14 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010092495940625668
# Adversariat: -0.00025979382917284966
# Adversariat_fake: 0.010092495940625668
# Adversariat_real: -0.010612083598971367
#
#
# Time left: ~0.056 minutes (Batches remaining: 1878).
#
#
# ------------------------------------------------------------
# EPOCH: 15
# ------------------------------------------------------------
# Step: 4695 / 6260 (Epoch: 15 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.00996393896639347
# Adversariat: -0.00027412082999944687
# Adversariat_fake: 0.00996393896639347
# Adversariat_real: -0.010512180626392365
#
#
# Time left: ~0.047 minutes (Batches remaining: 1565).
#
#
# ------------------------------------------------------------
# EPOCH: 16
# ------------------------------------------------------------
# Step: 5008 / 6260 (Epoch: 16 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.009959512390196323
# Adversariat: -0.0002126595936715603
# Adversariat_fake: 0.009959512390196323
# Adversariat_real: -0.010384831577539444
#
#
# Time left: ~0.038 minutes (Batches remaining: 1252).
#
#
# ------------------------------------------------------------
# EPOCH: 17
# ------------------------------------------------------------
# Step: 5321 / 6260 (Epoch: 17 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.009961185976862907
# Adversariat: -0.00022309180349111557
# Adversariat_fake: 0.009961185976862907
# Adversariat_real: -0.010407369583845139
#
#
# Time left: ~0.028 minutes (Batches remaining: 939).
#
#
# ------------------------------------------------------------
# EPOCH: 18
# ------------------------------------------------------------
# Step: 5634 / 6260 (Epoch: 18 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010003788396716118
# Adversariat: -0.0002132495865225792
# Adversariat_fake: 0.010003788396716118
# Adversariat_real: -0.010430287569761276
#
#
# Time left: ~0.019 minutes (Batches remaining: 626).
#
#
# ------------------------------------------------------------
# EPOCH: 19
# ------------------------------------------------------------
# Step: 5947 / 6260 (Epoch: 19 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010046616196632385
# Adversariat: -0.00023981602862477303
# Adversariat_fake: 0.010046616196632385
# Adversariat_real: -0.010526248253881931
#
#
# Time left: ~0.009 minutes (Batches remaining: 313).
#
#
# ------------------------------------------------------------
# EPOCH: 20
# ------------------------------------------------------------
# Step: 6260 / 6260 (Epoch: 20 / 20, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010007783770561218
# Adversariat: -0.00024270685389637947
# Adversariat_fake: 0.010007783770561218
# Adversariat_real: -0.010493197478353977
#
#
# Time left: ~0.0 minutes (Batches remaining: 0).

# %% [markdown]
# ## Inspection of results
# By calling `get_training_results()` on any GAN object, you can get a list of samples (generated out of a fixed noise vector), as well as the lists of losses of the generator and discriminator:

# %%
samples, losses = gan.get_training_results()

# %% [markdown]
# First, let's check what's the distribution of (flattened) samples during the last iteration:

# %%
plt.hist(samples.flatten(), bins=50);

# %% [markdown]
# And now let's look at the losses of the generator and critic during training - we can just call `vegans.utils.plot_losses()`:

# %%
fig, axs = plot_losses(losses)

# %% [markdown]
# And the sample covariance matrix we obtain we drawing samples from our newly-trained generator:

# %%
plot_generator_cov(generator)

# %% [markdown]
# It looks very similar to the original matrix.
